# %%
import numpy as np
lst1=[1,2,3]
array1=np.array(lst1)
array1
# Out:
# array([1, 2, 3])

# %%
type(lst1)
# Out:
# list

# %%
type(array1)
# Out:
# numpy.ndarray

# %% [markdown]
# ##perform mathematical operations on these datasets-Multiplication,Division

# %%
list2=[3,2,1]
array2=np.array(list2)
array2
# Out:
# array([3, 2, 1])

# %%
print("array2 multiplied by array1:",array1*array2)
print("array2 divided by array1:",array2/array1)
print("array2 raised to the power of array1:",array2**array1)
print(f"{array2}raised to the power of {array1}:,{array2**array1}")
# Out:
# array2 multiplied by array1: [3 4 3]
# array2 divided by array1: [3.         1.         0.33333333]
# array2 raised to the power of array1: [3 4 1]
# [3 2 1]raised to the power of [1 2 3]:,[3 4 1]

# %% [markdown]
# ##Part-2 Visualize the Dataset
# ##collect age,height,and weight

# %%
people=['Ann','Brandon','Chen','David']
age=[21,12,32,45]
weight=[55,35,77,68]
height=[160,135,170,165]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(weight,height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight of Patients in Kgs")
plt.show()

# %% [markdown]
# ##Generate Bar Plot

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=16,fontstyle='italic')

# main plot function 'bar'
plt.bar(x=people,height=weight,width=0.6,color='orange',edgecolor='k',alpha=0.6)
plt.xlabel("People",fontsize=15)
#plt.xticks(fontsize=14,rotation=30)
#plt.yticks(fontsize=14)
plt.ylabel("weight (in kgs)")
plt.show()

# %% [markdown]
# ##Access Data

# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_table("/content/data1.txt")
df1
# Out:
#   PEOPLE  AGE  HEIGHT  WEIGHT
# 0      A   12     5.6      34
# 1      B   40     4.5      60
# 2      C   34     5.5      55
# 3      D   23     6.0      65
# 4      E   12     5.9      30

# %%
data2

# %%
data2=pd.read_xlsx()

# %%
data3 = pd.read_excel("/content/data1.xls.xlsx")
data3
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0         NaN         NaN         NaN         NaN         NaN       Name
# 1         NaN         NaN         NaN         NaN         NaN    Harshan
# 2         NaN         NaN         NaN         NaN         NaN     Ramsai
# 3         NaN         NaN         NaN         NaN         NaN      Suhas
# 4         NaN         NaN         NaN         NaN         NaN     venkat
# 5         NaN         NaN         NaN         NaN         NaN      shiva
#
#   Unnamed: 6 Unnamed: 7
# 0     Height     Weight
# 1        155         75
# 2        100         35
# 3        125         65
# 4        178         70
# 5        165         90
